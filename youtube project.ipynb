# %% [markdown]
# 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
youtube_df=pd.read_csv("/Users/roshininambi/Downloads/youtube_dislike_dataset.csv")

# %%
youtube_df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
youtube_df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# -The dataframe has 37422 rows and 12 columns.
# -the first 11 columns has no null values and only comments column has null values.
# -The columns video_id,title,channel_id,channel_title,published_at,tags,description,comments have object data type and the columns view_count,likes,dislikes,comment_count have integer data type

# %% [markdown]
# 3.Check for the Percentage of the missing values and drop or impute them.

# %%
(youtube_df.isnull().sum() / youtube_df.shape[0] * 100).round(2)
# Out:
# video_id         0.00
# title            0.00
# channel_id       0.00
# channel_title    0.00
# published_at     0.00
# view_count       0.00
# likes            0.00
# dislikes         0.00
# comment_count    0.00
# tags             0.00
# description      0.00
# comments         0.42
# dtype: float64

# %%
youtube_df=youtube_df.dropna()

# %%
youtube_df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
youtube_df.describe().T
# Out:
#                  count          mean           std      min        25%  \
# view_count     37264.0  5.710821e+06  2.431304e+07  20368.0  514130.50
# likes          37264.0  1.672867e+05  5.384931e+05     22.0   13317.25
# dislikes       37264.0  4.996434e+03  3.075194e+04      3.0     282.75
# comment_count  37264.0  9.966953e+03  1.173465e+05      1.0     914.00
#
#                      50%         75%           max
# view_count     1321860.5  3674527.25  1.322797e+09
# likes            42556.0   130966.50  3.183768e+07
# dislikes           798.0     2466.25  2.397733e+06
# comment_count     2347.0     6212.00  1.607103e+07

# %%
-The mininum viewcount of the video is 20368 .The mean is greater than the median and is slightly positively skewed.
-the minimum likes are 22 and the mean is slightly larger than the median.
-the minimum diskes are 3 and the mean is greater than the median.
-The minimum comment count is 1 and the mean is greater than the median.

# %%
youtube_df.describe(include='object').T
# Out:
#                count unique  \
# video_id       37264  37264
# title          37264  36958
# channel_id     37264  10891
# channel_title  37264  10813
# published_at   37264  36617
# tags           37264  28705
# description    37264  35479
# comments       37264  37264
#
#                                                              top  freq
# video_id                                             LkdmvEWhKeo     1
# title                                                        www    21
# channel_id                              UCNAf1k0yIjyGu3k9BwAg3lg   533
# channel_title                                Sky Sports Football   533
# published_at                                 2020-10-16 04:00:10     6
# tags                                                              3808
# description                                                        587
# comments       Excited to see what the MNM trio can do  I'm l...     1

# %%
-The describe function tells us the number of values in each column,unique values and frequently occurred values.
-The video_id column has no duplicates which means it uniquely identifies each row.
-The comments columns tells us that each comments given by the user for the video the  is unique.

# %% [markdown]
# 5. Convert datatype of column published_at from object to pandas datetime.

# %%
youtube_df["published_at"]=pd.to_datetime(youtube_df["published_at"])

# %%
youtube_df["published_at"]
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: datetime64[ns]

# %% [markdown]
# 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
youtube_df["published_month"]=youtube_df["published_at"].dt.month

# %%
youtube_df["published_month"]
# Out:
# 0         7
# 1         6
# 2         9
# 3         3
# 4        12
#          ..
# 37417     2
# 37418     1
# 37419     6
# 37420    10
# 37421     5
# Name: published_month, Length: 37264, dtype: int64

# %% [markdown]
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
youtube_df["published_month"]=youtube_df.loc[:,"published_month"].replace({1:'Jan',2:"Feb",3:"March",4:"April",5:"May",6:"June",7:"July",8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"})

# %%
youtube_df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
youtube_df.groupby("published_month")["video_id"].count().sort_values()
# Out:
# published_month
# May      2073
# Jan      2099
# April    2119
# Feb      2125
# March    2248
# June     2305
# July     2331
# Dec      3063
# Aug      4250
# Nov      4821
# Sep      4854
# Oct      4976
# Name: video_id, dtype: int64

# %% [markdown]
# 9. Find the count of unique video_id, channel_id and channel_title.

# %%
youtube_df[["video_id","channel_id","channel_title"]].nunique()
# Out:
# video_id         37264
# channel_id       10891
# channel_title    10813
# dtype: int64

# %% [markdown]
# 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
youtube_df.groupby("channel_title")["video_id"].count().sort_values().head(10)
# Out:
# channel_title
#    SilverName                   1
# Mini Muka                       1
# Mini Ladd                       1
# MindYourLogic                   1
# Mind Body Tonic With Dr Sita    1
# Mimi Ar                         1
# Millyz                          1
# Milkair                         1
# Milissa Grande                  1
# MikuruSong                      1
# Name: video_id, dtype: int64

# %%
youtube_df.groupby("channel_title")["video_id"].count().sort_values(ascending=False).head(10)
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64

# %% [markdown]
# 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
youtube_df.groupby("title")["likes"].max().sort_values(ascending=False).head(1)
# Out:
# title
# BTS () 'Dynamite' Official MV    31837675
# Name: likes, dtype: int64

# %%
youtube_df.groupby("title")["likes"].max().sort_values().head(1)
# Out:
# title
# Leading the Charge | Circle K    22
# Name: likes, dtype: int64

# %% [markdown]
# -The video'Dynamite'song by BTS has more likes of around 31837675
# -The video Leading the charge has less likes of around 22

# %% [markdown]
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
youtube_df.groupby("title")["dislikes"].max().sort_values(ascending=False).head(1)
# Out:
# title
# Cuties | Official Trailer | Netflix    2397733
# Name: dislikes, dtype: int64

# %%
youtube_df.groupby("title")["dislikes"].max().sort_values().head(1)
# Out:
# title
# Tims For Good: A Taste Of The Familiar    3
# Name: dislikes, dtype: int64

# %%
-The video cuties has more diskes of around 2397733.
-The video Tims for good has less diskes of around 3.

# %% [markdown]
# 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
sns.scatterplot(data=youtube_df,x="view_count",y="dislikes")
# Out:
# <AxesSubplot: xlabel='view_count', ylabel='dislikes'>

# %%
-The columns view_count and diskes has no correlation with each other.
-Most of the data points are scattered evenly and only some data points have higher diskes.
-Hence we can say the number of views has no effect on how many people disliked the video.

# %% [markdown]
# 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
youtube_df.loc[youtube_df["published_month"] == "Jan"]
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
youtube_df[youtube_df["published_month"] == "Jan"].count()
# Out:
# video_id           2099
# title              2099
# channel_id         2099
# channel_title      2099
# published_at       2099
# view_count         2099
# likes              2099
# dislikes           2099
# comment_count      2099
# tags               2099
# description        2099
# comments           2099
# published_month    2099
# dtype: int64
